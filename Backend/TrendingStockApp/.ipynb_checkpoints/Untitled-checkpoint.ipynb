# %%
import tweepy as tw
import pandas as pd

auth = tweepy.OAuthHandler("aA9ZxW6NJzq8Q62sfrYhkUNt6", "xoVKPOpTTXczrml4BCdghhpUfrqdlmReQSXkiRaPNvg8pJG1rA")
api = tweepy.API(auth)

# %%
ticker_name = "TSLA"

# %%
search_words = "$" + ticker_name

tweets = tw.Cursor(api.search,
              q=search_words,
              result_type='popular',
              lang="en",).items(10)

tweets_list = []

for tweet in tweets:
    tweets_list.append(api.get_oembed("https://twitter.com/"+ str(tweet.user.screen_name) + "/status/" + str(tweet.id)))

# %%
tweets_list[3]
# Out:
# {'url': 'https://twitter.com/Investingcom/status/1383262993366929408',
#  'author_name': 'Investing.com',
#  'author_url': 'https://twitter.com/Investingcom',
#  'html': '<blockquote class="twitter-tweet"><p lang="en" dir="ltr">*CATHIE WOOD&#39;S ARK INVEST FUNDS SOLD 135K SHARES OF TESLA ON FRIDAY, VALUED AT $100 MLN<a href="https://twitter.com/search?q=%24TSLA&amp;src=ctag&amp;ref_src=twsrc%5Etfw">$TSLA</a> <a href="https://t.co/BPTJo6iVTK">pic.twitter.com/BPTJo6iVTK</a></p>&mdash; Investing.com (@Investingcom) <a href="https://twitter.com/Investingcom/status/1383262993366929408?ref_src=twsrc%5Etfw">April 17, 2021</a></blockquote>\n<script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>\n',
#  'width': 550,
#  'height': None,
#  'type': 'rich',
#  'cache_age': '3153600000',
#  'provider_name': 'Twitter',
#  'provider_url': 'https://twitter.com',
#  'version': '1.0'}

# %%
import pandas as pd

table = pd.read_html('https://unbiastock.com/TableReddit.php?compare2=all&compare_sector=6&mailnews=')
reddit_df = table[0]
reddit_df = reddit_df[['Ticker','Reddit Score 1','Previous Score','Score Change %','Stock Price $']]
reddit_df = reddit_df.rename(columns={"Reddit Score 1": "Reddit Score", "Score Change %": "Score Change", "Stock Price $": "Stock Price" })

# %%
reddit_df
# Out:
#    Ticker  Reddit Score  Previous Score Score Change Stock Price
# 0     ATH            23              16       43.75%      55.45$
# 1      AY            10              10           0%      39.04$
# 2    CLOV           120              72       66.67%       8.82$
# 3     CNI            23              16       43.75%     118.77$
# 4      FB            51              42       21.43%     306.18$
# 5     FCF            26              22       18.18%      14.41$
# 6     GEM            10              10           0%      40.42$
# 7    IMTL            22              20          10%       0.01$
# 8     IPO            26              22       18.18%      64.79$
# 9     JPM            23              16       43.75%      153.3$
# 10   KGKG            15              14        7.14%       0.03$
# 11    MGM             6               6           0%      40.26$
# 12   NFLX            11              10          10%     546.54$
# 13   RIDE            41              34       20.59%      10.02$
# 14   SNAP            11              10          10%      61.25$
# 15   SOME             8               0           0%         41$
# 16   THCB            12               0           0%      11.02$
# 17     TU            26              22       18.18%      20.84$
# 18    VTI            18              18           0%     217.15$
